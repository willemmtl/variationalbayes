# %%
using Distributions, Gadfly

# %%
x = 0.1:10

plot(x=x, y=logpdf.(Gamma(26, 0.2), x), Geom.line)
# Out:
# Plot(...)

# %%
x = -10:0.1:10

plot(x=x, y=logpdf.(Cauchy(1, 10000), x), Geom.line)
# Out:
# Plot(...)

# %%
x = -10:0.1:10

plot(x=x, y=logpdf.(Chisq(3), x), Geom.line)
# Out:
# Plot(...)

# %%
x = -10:0.1:10

plot(x=x, y=logpdf.(Erlang(5, 0.01), x), Geom.line)
# Out:
# Plot(...)

# %%
x = -10:0.1:10

plot(x=x, y=logpdf.(FDist(1, 10), x), Geom.line)
# Out:
# Plot(...)

# %%
x = -10:0.1:10

plot(x=x, y=logpdf.(Frechet(0.001, 0.001), x), Geom.line)
# Out:
# Plot(...)

# %%
x = -10:0.1:10

plot(x=x, y=logpdf.(Gumbel(0, 1), x), Geom.line)
# Out:
# Plot(...)

# %%
x = 0:0.1:10

plot(x=x, y=logpdf.(InverseGamma(1, 0.3), x), Geom.line)
# Out:
# Plot(...)
